# %% [markdown]
# # P03_03_LSTM_Multivariate

# %%
section_fig_main_title = 'P03_03_LSTM_Multivariate_'

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.6.0'

# %%
import sys
# print(sys.executable)

# %%
# !/Users/amin/Desktop/proj/env/bin/python -m pip install matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
import gif
from tqdm import tqdm

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ### Read data

# %%
csv_path = "../Data/jena_climate_2009_2016.csv"
df = pd.read_csv(csv_path, index_col=0, parse_dates=True)

# %%
df.head()
# Out:
#                      p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# Date Time
# 2009-01-01 00:10:00    996.52     -8.02    265.40        -8.90    93.3
# 2009-01-01 00:20:00    996.57     -8.41    265.01        -9.28    93.4
# 2009-01-01 00:30:00    996.53     -8.51    264.91        -9.31    93.9
# 2009-01-01 00:40:00    996.51     -8.31    265.12        -9.07    94.2
# 2009-01-01 00:50:00    996.51     -8.27    265.15        -9.04    94.1
#
#                      VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# Date Time
# 2009-01-01 00:10:00          3.33          3.11          0.22       1.94
# 2009-01-01 00:20:00          3.23          3.02          0.21       1.89
# 2009-01-01 00:30:00          3.21          3.01          0.20       1.88
# 2009-01-01 00:40:00          3.26          3.07          0.19       1.92
# 2009-01-01 00:50:00          3.27          3.08          0.19       1.92
#
#                      H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  \
# Date Time
# 2009-01-01 00:10:00             3.12       1307.75      1.03           1.75
# 2009-01-01 00:20:00             3.03       1309.80      0.72           1.50
# 2009-01-01 00:30:00             3.02       1310.24      0.19           0.63
# 2009-01-01 00:40:00             3.08       1309.19      0.34           0.50
# 2009-01-01 00:50:00             3.09       1309.00      0.32           0.63
#
#                      wd (deg)
# Date Time
# 2009-01-01 00:10:00     152.3
# 2009-01-01 00:20:00     136.1
# 2009-01-01 00:30:00     171.6
# 2009-01-01 00:40:00     198.0
# 2009-01-01 00:50:00     214.3

# %% [markdown]
# Base on P02_03 EDA analysis I choose following columns for modeling.

# %% [markdown]
# The essential parameters to be considered for modeling are as follows.
#
# ```
# 'p (mbar)','Tpot (K)','Tdew (degC)','VPact (mbar)','sh (g/kg)','H2OC (mmol/mol)','rho (g/m**3)','wd (deg)'
# ```

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
# plt.style.use('fivethirtyeight')
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
# from keras.optimizers import SGD
from tensorflow.keras.optimizers import SGD

import math
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Split the data

# %%
split_fraction = 0.715
train_split = int(split_fraction * int(df.shape[0]))
step = 6

past = 720
future = 72
learning_rate = 0.001
batch_size = 256
epochs = 10

def normalize(data, train_split):
    data_mean = data[:train_split].mean(axis=0)
    data_std = data[:train_split].std(axis=0)
    return (data - data_mean) / data_std

# %%
selected_features = ['p (mbar)','Tpot (K)','Tdew (degC)',
                     'VPact (mbar)','sh (g/kg)',
                     'H2OC (mmol/mol)','rho (g/m**3)','wd (deg)']

features = df[selected_features]
features.index = df.index

# %%
features.head()
# Out:
#                      p (mbar)  Tpot (K)  Tdew (degC)  VPact (mbar)  sh (g/kg)  \
# Date Time
# 2009-01-01 00:10:00    996.52    265.40        -8.90          3.11       1.94
# 2009-01-01 00:20:00    996.57    265.01        -9.28          3.02       1.89
# 2009-01-01 00:30:00    996.53    264.91        -9.31          3.01       1.88
# 2009-01-01 00:40:00    996.51    265.12        -9.07          3.07       1.92
# 2009-01-01 00:50:00    996.51    265.15        -9.04          3.08       1.92
#
#                      H2OC (mmol/mol)  rho (g/m**3)  wd (deg)
# Date Time
# 2009-01-01 00:10:00             3.12       1307.75     152.3
# 2009-01-01 00:20:00             3.03       1309.80     136.1
# 2009-01-01 00:30:00             3.02       1310.24     171.6
# 2009-01-01 00:40:00             3.08       1309.19     198.0
# 2009-01-01 00:50:00             3.09       1309.00     214.3

# %%
features.shape
# Out:
# (420551, 8)

# %% [markdown]
# ### Normalizing data

# %%
features = normalize(features.values, train_split)
features = pd.DataFrame(features)
features.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.955451 -2.060649 -1.953135 -1.497879 -1.500927 -1.503167  2.237658
# 1  0.961528 -2.105453 -2.007509 -1.519123 -1.519521 -1.524154  2.287838
# 2  0.956666 -2.116941 -2.011802 -1.521483 -1.523239 -1.526486  2.298608
# 3  0.954236 -2.092816 -1.977460 -1.507321 -1.508364 -1.512494  2.272906
# 4  0.954236 -2.089370 -1.973168 -1.504960 -1.508364 -1.510162  2.268256
#
#           7
# 0 -0.241025
# 1 -0.425626
# 2 -0.021100
# 3  0.279731
# 4  0.465471

# %%
train_data = features.loc[0 : train_split - 1]
val_data = features.loc[train_split:]

# %%
train_data.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.955451 -2.060649 -1.953135 -1.497879 -1.500927 -1.503167  2.237658
# 1  0.961528 -2.105453 -2.007509 -1.519123 -1.519521 -1.524154  2.287838
# 2  0.956666 -2.116941 -2.011802 -1.521483 -1.523239 -1.526486  2.298608
# 3  0.954236 -2.092816 -1.977460 -1.507321 -1.508364 -1.512494  2.272906
# 4  0.954236 -2.089370 -1.973168 -1.504960 -1.508364 -1.510162  2.268256
#
#           7
# 0 -0.241025
# 1 -0.425626
# 2 -0.021100
# 3  0.279731
# 4  0.465471

# %%
start = past + future
end = start + train_split
print('start = ', start)
print('end = ', end)
print('train_split = ', train_split)
sequence_length = int(past / step)
print('sequence_length = ', sequence_length)
# Out:
# start =  792
# end =  301485
# train_split =  300693
# sequence_length =  120

# %% [markdown]
# ### Find out the temprature for next 72 hours

# %%
x_train = train_data[[i for i in range(7)]].values
y_train = features.iloc[start:end][[1]]

# %%
print('type = ', type(x_train))
print("len of ", len(x_train))
x_train
# Out:
# type =  <class 'numpy.ndarray'>
# len of  300693
# array([[ 0.95545114, -2.06064923, -1.95313513, ..., -1.50092673,
#         -1.50316656,  2.23765845],
#        [ 0.96152792, -2.10545302, -2.00750928, ..., -1.51952063,
#         -1.52415369,  2.28783773],
#        [ 0.9566665 , -2.11694117, -2.01180197, ..., -1.52323941,
#         -1.52648559,  2.29860792],
#        ...,
#        [-0.11163086,  0.9067405 ,  1.23204518, ...,  1.39228456,
#          1.39305744, -0.92045437],
#        [-0.11770764,  0.90099643,  1.22775249, ...,  1.38856578,
#          1.38606173, -0.91653794],
#        [-0.11041551,  0.86768079,  1.23204518, ...,  1.39600334,
#          1.39538935, -0.88740948]])

# %%
print('type = ', type(y_train))
print("size = ", y_train.size)
y_train.head()
# Out:
# type =  <class 'pandas.core.frame.DataFrame'>
# size =  300693
#             1
# 792 -2.810826
# 793 -2.766022
# 794 -2.705135
# 795 -2.659182
# 796 -2.571872

# %% [markdown]
# ### Preprocessing data

# %%
dataset_train = keras.preprocessing.timeseries_dataset_from_array(
                                                                x_train,
                                                                y_train,
                                                                sequence_length=sequence_length,
                                                                sampling_rate=step,
                                                                batch_size=batch_size,
                                                                )

# %%
x_end = len(val_data) - past - future

label_start = train_split + past + future

x_val = val_data.iloc[:x_end][[i for i in range(7)]].values
y_val = features.iloc[label_start:][[1]]

dataset_val = keras.preprocessing.timeseries_dataset_from_array(x_val,
                                                                y_val,
                                                                sequence_length=sequence_length,
                                                                sampling_rate=step,
                                                                batch_size=batch_size,
                                                                )


for batch in dataset_train.take(1):
    inputs, targets = batch

print("Input shape:", inputs.numpy().shape)
print("Target shape:", targets.numpy().shape)
# Out:
# Input shape: (256, 120, 7)
# Target shape: (256, 1)
# 2021-10-17 12:24:39.626867: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)

# %% [markdown]
# ### Assemble keras model

# %%
inputs = keras.layers.Input(shape=(inputs.shape[1], 
                                   inputs.shape[2]))

lstm_out = keras.layers.LSTM(32)(inputs)
outputs = keras.layers.Dense(1)(lstm_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), 
              loss="mse")

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 120, 7)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                5120
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# =================================================================
# Total params: 5,153
# Trainable params: 5,153
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Fit the model

# %%
path_checkpoint = "model_checkpoint.h5"
es_callback = keras.callbacks.EarlyStopping(monitor="val_loss", 
                                            min_delta=0, 
                                            patience=5)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
                                                    monitor="val_loss",
                                                    filepath=path_checkpoint,
                                                    verbose=1,
                                                    save_weights_only=True,
                                                    save_best_only=True,
                                                )

history = model.fit(
                    dataset_train,
                    epochs=epochs,
                    validation_data=dataset_val,
                    callbacks=[es_callback, modelckpt_callback],
                )
# Out:
# Epoch 1/10
# 1172/1172 [==============================] - 78s 65ms/step - loss: 0.2245 - val_loss: 0.1643
#
# Epoch 00001: val_loss improved from inf to 0.16428, saving model to model_checkpoint.h5
# Epoch 2/10
# 1172/1172 [==============================] - 75s 64ms/step - loss: 0.1375 - val_loss: 0.1516
#
# Epoch 00002: val_loss improved from 0.16428 to 0.15157, saving model to model_checkpoint.h5
# Epoch 3/10
# 1172/1172 [==============================] - 78s 67ms/step - loss: 0.1302 - val_loss: 0.1508
#
# Epoch 00003: val_loss improved from 0.15157 to 0.15083, saving model to model_checkpoint.h5
# Epoch 4/10
# 1172/1172 [==============================] - 76s 65ms/step - loss: 0.1241 - val_loss: 0.1476
#
# Epoch 00004: val_loss improved from 0.15083 to 0.14760, saving model to model_checkpoint.h5
# Epoch 5/10
# 1172/1172 [==============================] - 75s 64ms/step - loss: 0.1215 - val_loss: 0.1453
#
# Epoch 00005: val_loss improved from 0.14760 to 0.14534, saving model to model_checkpoint.h5
# Epoch 6/10
# 1172/1172 [==============================] - 75s 64ms/step - loss: 0.1193 - val_loss: 0.1442
#
# Epoch 00006: val_loss improved from 0.14534 to 0.14422, saving model to model_checkpoint.h5
# Epoch 7/10
# 1172/1172 [==============================] - 75s 64ms/step - loss: 0.1174 - val_loss: 0.1436
#
# Epoch 00007: val_loss improved from 0.14422 to 0.14357, saving model to model_checkpoint.h5
# Epoch 8/10
# 1172/1172 [==============================] - 77s 66ms/step - loss: 0.1159 - val_loss: 0.1388
#
# Epoch 00008: val_loss improved from 0.14357 to 0.13884, saving model to model_checkpoint.h5
# Epoch 9/10
# 1172/1172 [==============================] - 76s 65ms/step - loss: 0.1147 - val_loss: 0.1369
#
# Epoch 00009: val_loss improved from 0.13884 to 0.13691, saving model to model_checkpoint.h5
# Epoch 10/10
# 1172/1172 [==============================] - 82s 70ms/step - loss: 0.1127 - val_loss: 0.1345
#
# Epoch 00010: val_loss improved from 0.13691 to 0.13450, saving model to model_checkpoint.h5

# %%
def visualize_loss(history, title):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(len(loss))
    plt.figure()
    plt.plot(epochs, loss, "b", label="Training loss")
    plt.plot(epochs, val_loss, "r", label="Validation loss")
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()


visualize_loss(history, "Training and Validation Loss")

# %%
def show_plot(plot_data, delta, title):
    labels = ["History", "True Future", "Model Prediction"]
    marker = [".-", "rx", "go"]
    time_steps = list(range(-(plot_data[0].shape[0]), 0))
    if delta:
        future = delta
    else:
        future = 0

    plt.title(title)
    for i, val in enumerate(plot_data):
        if i:
            plt.plot(future, plot_data[i], marker[i], markersize=10, label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend()
    plt.xlim([time_steps[0], (future + 5) * 2])
    plt.xlabel("Time-Step")
    plt.show()
    return


for x, y in dataset_val.take(5):
    show_plot(
        [x[0][:, 1].numpy(), y[0].numpy(), model.predict(x)[0]],
        12,
        "Single Step Prediction",
    )
